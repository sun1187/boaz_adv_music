# %% [markdown]
# 4) **user의 피드백을 반영하고 싶다면?**
#
# - user가 추천한 노래들을 바탕으로 평가를 매김
# - ex) 1번 노래 5점, 2번 노래 3점, 3번 노래 1점
# - 1번 노래의 정보들(위에서 뽑아낸 tag와 가중치)을 활용
# - 높게 점수 매긴 노래와 관련된 애들을 더 추천하고, 낮게 매긴 노래와 관련된 애들은 추천항목에서 배제

# %%
import pandas as pd

data= pd.read_excel('/content/drive/Shareddrives/BOAZ_Adv/recommender_data.xlsx')
data
# Out:
#         song id  ...     emotion max
# 0             0  ...         ['우울한']
# 1             3  ...         ['행복한']
# 2             5  ...         ['행복한']
# 3             6  ...  ['행복한', '경쾌한']
# 4             9  ...         ['우울한']
# ...         ...  ...             ...
# 395360   707979  ...         ['행복한']
# 395361   707980  ...         ['잔잔한']
# 395362   707982  ...         ['행복한']
# 395363   707986  ...  ['잔잔한', '우울한']
# 395364   707987  ...         ['잔잔한']
#
# [395365 rows x 5 columns]

# %%
song = pd.read_json('/content/drive/Shareddrives/BOAZ_Adv/melon_data/song_meta.json')
song.head()
# Out:
#   song_gn_dtl_gnr_basket  issue_date  ... artist_name_basket  id
# 0               [GN0901]    20140512  ...  [Various Artists]   0
# 1       [GN1601, GN1606]    20080421  ...   [Murray Perahia]   1
# 2               [GN0901]    20180518  ...    [Peter Gabriel]   2
# 3       [GN1102, GN1101]    20151016  ...           [Matoma]   3
# 4       [GN1802, GN1801]    20110824  ...         [Jude Law]   4
#
# [5 rows x 9 columns]

# %%
song.rename(columns={"song_gn_dtl_gnr_basket":"곡 세부 장르 리스트", "issue_date":"발매일", "album_name": "앨범 명", "album_id":"앨범 ID", "artist_id_basket":"아티스트 ID 리스트", "song_name":"곡 제목", "song_gn_gnr_basket":"곡 장르 리스트", "artist_name_basket":"아티스트 리스트","id":"곡 ID"},inplace= True )
song.head()
# Out:
#         곡 세부 장르 리스트       발매일  ...           아티스트 리스트  곡 ID
# 0          [GN0901]  20140512  ...  [Various Artists]     0
# 1  [GN1601, GN1606]  20080421  ...   [Murray Perahia]     1
# 2          [GN0901]  20180518  ...    [Peter Gabriel]     2
# 3  [GN1102, GN1101]  20151016  ...           [Matoma]     3
# 4  [GN1802, GN1801]  20110824  ...         [Jude Law]     4
#
# [5 rows x 9 columns]

# %%
song= song[['곡 ID','곡 제목','아티스트 리스트']]
song
# Out:
#           곡 ID  ...           아티스트 리스트
# 0            0  ...  [Various Artists]
# 1            1  ...   [Murray Perahia]
# 2            2  ...    [Peter Gabriel]
# 3            3  ...           [Matoma]
# 4            4  ...         [Jude Law]
# ...        ...  ...                ...
# 707984  707984  ...        [Fela Kuti]
# 707985  707985  ...     [Cyndi Lauper]
# 707986  707986  ...              [윤종신]
# 707987  707987  ...     [Nature Piano]
# 707988  707988  ...              [김경호]
#
# [707989 rows x 3 columns]

# %%
song_data = pd.merge(data,song,how='left',left_on='song id',right_on ='곡 ID')
song_data = song_data.drop('song id',axis = 1)
song_data
# Out:
#                                                 tag count  ...                                     아티스트 리스트
# 0                {'비오는날': 2, '드라이브': 1, '추억': 1, '회상': 1}  ...                            [Various Artists]
# 1       {'드라이브': 2, '여행': 1, '기분전환': 3, '신나는': 3, '클럽'...  ...                                     [Matoma]
# 2                {'비오는날': 1, '휴식': 1, '힐링': 1, '기분전환': 1}  ...                                [Bye, Lupita]
# 3                                      {'산책': 1, '조깅': 1}  ...  [Herbert Blomstedt, San Francisco Symphony]
# 4                                               {'위로': 1}  ...                                         [진호]
# ...                                                   ...  ...                                          ...
# 395360                             {'기분전환': 1, '드라이브': 1}  ...                             [Herbie Hancock]
# 395361  {'겨울': 1, '밤': 1, '카페': 1, '겨울밤': 1, '센치': 1, ...  ...                                 [SUMIN (수민)]
# 395362                                         {'신나는': 1}  ...                                   [조승우와 데블스]
# 395363  {'카페': 1, '잔잔한': 4, '추억': 3, '위로': 2, '힐링': 1,...  ...                                        [윤종신]
# 395364  {'집중': 1, '노동요': 1, '새벽': 1, '오후': 1, '자장가': 1...  ...                               [Nature Piano]
#
# [395365 rows x 7 columns]

# %%
user_tag = song_data[song_data['tag max'].str.contains('휴식')]
user_tag
# Out:
#                                                 tag count  ...          아티스트 리스트
# 2                {'비오는날': 1, '휴식': 1, '힐링': 1, '기분전환': 1}  ...     [Bye, Lupita]
# 19      {'편안한': 1, '휴식': 1, '기분전환': 1, '가을': 1, '잔잔한': 1}  ...             [이호석]
# 44                           {'힐링': 1, '휴식': 1, '잔잔한': 1}  ...             [신해철]
# 47      {'힐링': 1, '휴식': 2, '설렘': 2, '사랑': 2, '기분전환': 1...  ...             [이민정]
# 58                   {'힐링': 1, '휴식': 1, '추억': 1, '회상': 1}  ...     [The Nucleus]
# ...                                                   ...  ...               ...
# 395355  {'사랑': 3, '기분전환': 1, '가을': 1, '힐링': 4, '휴식': 4...  ...  [헤리티지(Heritage)]
# 395357                      {'휴식': 1, '여유': 1, '부드러운': 1}  ...          [Djavan]
# 395358                      {'힐링': 1, '휴식': 1, '기분전환': 1}  ...    [Taylor Swift]
# 395359  {'신나는': 2, '잔잔한': 2, '새벽감성': 1, '따뜻한': 1, '서정적...  ...        [Westlife]
# 395361  {'겨울': 1, '밤': 1, '카페': 1, '겨울밤': 1, '센치': 1, ...  ...      [SUMIN (수민)]
#
# [54957 rows x 7 columns]

# %%
user_emotion = song_data[song_data['emotion max'].str.contains('편안한')]
user_emotion
# Out:
#                                                 tag count  ...                                           아티스트 리스트
# 67      {'겨울': 1, '스트레스': 1, '출근': 1, '드라이브': 1, '퇴근':...  ...                                              [조장혁]
# 200                                   {'여행': 1, '편안한': 1}  ...                                       [John Hiatt]
# 215                                            {'편안한': 1}  ...  [Wolfgang Meyer, Berliner Philharmoniker, Herb...
# 247     {'차분한': 1, '조용한': 1, '자장가': 1, '편안한': 3, '흐린날'...  ...                               [Harold Mabern Trio]
# 396     {'아름다운': 1, '낮잠': 3, '힐링': 2, '잠들기전': 1, '불면증'...  ...                                           [오르골 엔젤]
# ...                                                   ...  ...                                                ...
# 395154                      {'기분전환': 1, '공감': 1, '위로': 1}  ...                                  [블루램 (Blue lamb)]
# 395190                         {'햇살': 1, '봄': 1, '카페': 1}  ...                                   [Yuhki Kuramoto]
# 395279  {'아련한': 1, '기분전환': 1, '부드러운': 2, '신나': 1, '따듯한...  ...                                   [Linda Ronstadt]
# 395302              {'꿀잠': 2, '낮잠': 2, '자장가': 1, '숙면': 1}  ...                                          [태교음악 베베]
# 395357                      {'휴식': 1, '여유': 1, '부드러운': 1}  ...                                           [Djavan]
#
# [4105 rows x 7 columns]

# %%
tag_id = set(user_tag['곡 ID'].unique())
emotion_id = set(user_emotion['곡 ID'].unique())

# %%
intersection = tag_id & emotion_id
intersection = list(intersection)

# %%
len(intersection)
# Out:
# 446

# %%
intersection
# Out:
# [485376,
#  348170,
#  6160,
#  24595,
#  528406,
#  460825,
#  360474,
#  264220,
#  100381,
#  585758,
#  583711,
#  278561,
#  378915,
#  81960,
#  190504,
#  587823,
#  380978,
#  325696,
#  71746,
#  247880,
#  280652,
#  528465,
#  135250,
#  276563,
#  583766,
#  159830,
#  567384,
#  245852,
#  155742,
#  559217,
#  143473,
#  491639,
#  47229,
#  610431,
#  237698,
#  436358,
#  665736,
#  686221,
#  333974,
#  18583,
#  10402,
#  475306,
#  706733,
#  606384,
#  39091,
#  282805,
#  39093,
#  196792,
#  145601,
#  217282,
#  51404,
#  389324,
#  209110,
#  567543,
#  250114,
#  272646,
#  131349,
#  258328,
#  358682,
#  473377,
#  438566,
#  184619,
#  563500,
#  18733,
#  157997,
#  377149,
#  246081,
#  14657,
#  239941,
#  571721,
#  393554,
#  641367,
#  336217,
#  6499,
#  493925,
#  487791,
#  268655,
#  45427,
#  702837,
#  37238,
#  483709,
#  399744,
#  467329,
#  252299,
#  467340,
#  588173,
#  336273,
#  526738,
#  164250,
#  180637,
#  102822,
#  438697,
#  700843,
#  72115,
#  65972,
#  498105,
#  283078,
#  307655,
#  72137,
#  195023,
#  545240,
#  483801,
#  256473,
#  426466,
#  205284,
#  102884,
#  678374,
#  539111,
#  225768,
#  555499,
#  664050,
#  580083,
#  678397,
#  76286,
#  125442,
#  240131,
#  256514,
#  610821,
#  371212,
#  506382,
#  436759,
#  21016,
#  530974,
#  268836,
#  248359,
#  4660,
#  137781,
#  469562,
#  551482,
#  215622,
#  545356,
#  107091,
#  559719,
#  596586,
#  455276,
#  410221,
#  533106,
#  207484,
#  516746,
#  270988,
#  692881,
#  416402,
#  623251,
#  537235,
#  98975,
#  336543,
#  354978,
#  428710,
#  273064,
#  615083,
#  15021,
#  658099,
#  144055,
#  690882,
#  635586,
#  381635,
#  348869,
#  246470,
#  322250,
#  432843,
#  512717,
#  15054,
#  617185,
#  332525,
#  584431,
#  234223,
#  522996,
#  369400,
#  684792,
#  262908,
#  561928,
#  168715,
#  181008,
#  559889,
#  498448,
#  373525,
#  310038,
#  25372,
#  557852,
#  170781,
#  361249,
#  434981,
#  396077,
#  652083,
#  35649,
#  70469,
#  109385,
#  267082,
#  504650,
#  498509,
#  680782,
#  314191,
#  635728,
#  521041,
#  680786,
#  211793,
#  533332,
#  242521,
#  553817,
#  93027,
#  39783,
#  58216,
#  140140,
#  295790,
#  541550,
#  70512,
#  222065,
#  275312,
#  318320,
#  455544,
#  510844,
#  148351,
#  447363,
#  211850,
#  580493,
#  512917,
#  463766,
#  662423,
#  195480,
#  629656,
#  209824,
#  183203,
#  91044,
#  658346,
#  564140,
#  265141,
#  142271,
#  494536,
#  160717,
#  594894,
#  125903,
#  689106,
#  191452,
#  426974,
#  533480,
#  31732,
#  586745,
#  355329,
#  209921,
#  480260,
#  138248,
#  115726,
#  93203,
#  668697,
#  277530,
#  531489,
#  271399,
#  285736,
#  58411,
#  244794,
#  582715,
#  627793,
#  242777,
#  601183,
#  330848,
#  580708,
#  93285,
#  404586,
#  83053,
#  603247,
#  175220,
#  633972,
#  203893,
#  173175,
#  337021,
#  533630,
#  76929,
#  271495,
#  27787,
#  672908,
#  507030,
#  443544,
#  629917,
#  87201,
#  445604,
#  95400,
#  314539,
#  181426,
#  537790,
#  480451,
#  496848,
#  670930,
#  644307,
#  378078,
#  253151,
#  683232,
#  120035,
#  419053,
#  228599,
#  7416,
#  312571,
#  109827,
#  201988,
#  552201,
#  120074,
#  498961,
#  351511,
#  507160,
#  185627,
#  318747,
#  3361,
#  288045,
#  3373,
#  101679,
#  29998,
#  611638,
#  77114,
#  550203,
#  269638,
#  511303,
#  283975,
#  126282,
#  660814,
#  441684,
#  109909,
#  77143,
#  548184,
#  615775,
#  501090,
#  32102,
#  611699,
#  413044,
#  415094,
#  54648,
#  439673,
#  523642,
#  707974,
#  130440,
#  478601,
#  243083,
#  69013,
#  656790,
#  529813,
#  681369,
#  200092,
#  265631,
#  617901,
#  677293,
#  654767,
#  535987,
#  384441,
#  443842,
#  527845,
#  60902,
#  46569,
#  294380,
#  429551,
#  347633,
#  675328,
#  398848,
#  611844,
#  413212,
#  550430,
#  595488,
#  665142,
#  81462,
#  323135,
#  319040,
#  112193,
#  581185,
#  435789,
#  216654,
#  540244,
#  693846,
#  18008,
#  532076,
#  128622,
#  704113,
#  579187,
#  222838,
#  128634,
#  32379,
#  269949,
#  528000,
#  671360,
#  167554,
#  173699,
#  208538,
#  468637,
#  130718,
#  32418,
#  175779,
#  120485,
#  26281,
#  575147,
#  186028,
#  157361,
#  44728,
#  24249,
#  151241,
#  259786,
#  407248,
#  607954,
#  337622,
#  364247,
#  175840,
#  104162,
#  372459,
#  382714,
#  702202,
#  505599,
#  296712,
#  331537,
#  229143,
#  526108,
#  689957,
#  677678,
#  388912,
#  171828,
#  681782,
#  507703,
#  444218,
#  460603,
#  483134,
#  440134,
#  606025,
#  380748,
#  431948,
#  67429,
#  567144,
#  515949,
#  249718,
#  102273,
#  278409,
#  614284,
#  468877,
#  184218,
#  706459,
#  481192,
#  386987,
#  417709,
#  485295,
#  212920,
#  423866,
#  497598,
#  102344,
#  235471,
#  438227,
#  419801,
#  303067,
#  255964,
#  2013,
#  276444,
#  688102,
#  679926,
#  501757]

# %%
res  =[]
for i in intersection:
  ls = song_data[song_data['곡 ID'] == i].index[0]
  res.append(ls)

print(len(res))
# Out:
# 446

# %%
selected = song_data.iloc[res]
selected.tail()
# Out:
#                                                 tag count  ...                        아티스트 리스트
# 1120                         {'편안한': 1, '힐링': 1, '휴식': 1}  ...                      [이생강, 김광석]
# 154180  {'휴식': 2, '봄': 1, '주말': 1, '잔잔한': 1, '오후': 1, ...  ...             [Rachel Chinouriri]
# 384244                         {'휴식': 1, '집': 1, '새해': 1}  ...          [David Hazeltine Trio]
# 379738  {'기분좋은': 1, '휴식': 1, '카페': 1, '집': 1, '일상': 1,...  ...  [Marry Waterson, Emily Barker]
# 280181  {'퇴근': 1, '휴식': 1, '드라이브': 1, '위로': 1, '힐링': 1...  ...                    [Etta Jones]
#
# [5 rows x 7 columns]

# %%
selected_sample  = selected.sample(n=15,random_state=42)
selected_sample
# Out:
#                                                 tag count  ...           아티스트 리스트
# 141012  {'휴식': 1, '여유': 1, '집': 1, '힐링': 1, '포근한': 1, ...  ...  [Pete Huttlinger]
# 62385                        {'휴식': 1, '편안한': 1, '힙한': 1}  ...             [Roro]
# 340971             {'편안함': 1, '힐링': 1, '뮤지컬': 1, '휴식': 1}  ...           [Hauser]
# 155288  {'저녁': 1, '잔잔한': 1, '눈': 1, '분위기': 1, '일상': 3,...  ...             [카더가든]
# 219799                        {'치유': 1, '휴식': 1, '위로': 1}  ...              [NAK]
# 79821                                 {'편안함': 1, '휴식': 1}  ...      [Brian Temba]
# 354905  {'따듯한': 1, '휴식': 1, '잔잔한': 1, '퇴근': 1, '사색': 1...  ...             [커피소년]
# 20689               {'위로': 1, '휴식': 1, '힐링': 1, '편안한': 1}  ...      [Diana Krall]
# 120873                       {'휴식': 1, '편안함': 1, '마음': 1}  ...     [Kenji Nakagi]
# 344988  {'카페': 1, '잔잔한': 2, '기억': 1, '휴식': 3, '일상': 1,...  ...              [라벤다]
# 152046                                 {'휴식': 1, '일상': 1}  ...             [SIM2]
# 152274  {'집': 2, '힐링': 2, '휴식': 2, '몽환적인': 1, '분위기': 1...  ...            [Daste]
# 393213                                {'휴식': 1, '편안한': 1}  ...              [Jjj]
# 70248   {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...           [공부 도우미]
# 339380              {'잔잔': 1, '휴식': 1, '낮잠': 1, '편안한': 1}  ...  [Monma, cocabona]
#
# [15 rows x 7 columns]

# %%
selected_sample['점수']=0
selected_sample
# Out:
#                                                 tag count  ... 점수
# 141012  {'휴식': 1, '여유': 1, '집': 1, '힐링': 1, '포근한': 1, ...  ...  0
# 62385                        {'휴식': 1, '편안한': 1, '힙한': 1}  ...  0
# 340971             {'편안함': 1, '힐링': 1, '뮤지컬': 1, '휴식': 1}  ...  0
# 155288  {'저녁': 1, '잔잔한': 1, '눈': 1, '분위기': 1, '일상': 3,...  ...  0
# 219799                        {'치유': 1, '휴식': 1, '위로': 1}  ...  0
# 79821                                 {'편안함': 1, '휴식': 1}  ...  0
# 354905  {'따듯한': 1, '휴식': 1, '잔잔한': 1, '퇴근': 1, '사색': 1...  ...  0
# 20689               {'위로': 1, '휴식': 1, '힐링': 1, '편안한': 1}  ...  0
# 120873                       {'휴식': 1, '편안함': 1, '마음': 1}  ...  0
# 344988  {'카페': 1, '잔잔한': 2, '기억': 1, '휴식': 3, '일상': 1,...  ...  0
# 152046                                 {'휴식': 1, '일상': 1}  ...  0
# 152274  {'집': 2, '힐링': 2, '휴식': 2, '몽환적인': 1, '분위기': 1...  ...  0
# 393213                                {'휴식': 1, '편안한': 1}  ...  0
# 70248   {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...  0
# 339380              {'잔잔': 1, '휴식': 1, '낮잠': 1, '편안한': 1}  ...  0
#
# [15 rows x 8 columns]

# %%
name = list(selected_sample['곡 제목'])



score=[]
for i in name:
  s = input(f'\'{i}\' 의 점수를 입력해주세요   ',)
  score.append(int(s))
# Out:
# 'Si Bheag, Si Mhor' 의 점수를 입력해주세요   5
# 'Mine' 의 점수를 입력해주세요   5
# 'River Flows in You' 의 점수를 입력해주세요   4
# 'Somebody (Feat. Paloalto, Ugly Duck)' 의 점수를 입력해주세요   10
# 'Fragments' 의 점수를 입력해주세요   3
# 'T.I.M.T (This Is My Time)' 의 점수를 입력해주세요   3
# '서서히' 의 점수를 입력해주세요   10
# 'How Insensitive' 의 점수를 입력해주세요   6
# 'Bach : Cello Suite No.6 In D Major BWV.1012 - I. Prelude (바흐 : 무반주 첼로 모음곡 6번 라장조 - 1번. 전주곡)' 의 점수를 입력해주세요   8
# 'Soul Of The Wind' 의 점수를 입력해주세요   7
# 'Chocolate (feat. SWRY)' 의 점수를 입력해주세요   7
# 'Thinkin&#39; Of' 의 점수를 입력해주세요   3
# 'girls (Feat. Taha Vanilla as Senshi1992)' 의 점수를 입력해주세요   2
# 'Brahms : Double Concerto For Violin And Cello In A Minor Op.102 - II. Andante (브람스 : 바이올린과 첼로를 위한 2중주 협주곡 가단조 작품번호 102 - 2악장)' 의 점수를 입력해주세요   10
# 'Pyra' 의 점수를 입력해주세요   3

# %%
mn = min(score)
mx = max(score)

# %%
# score_list=[10,9,3,4,3,2,3,4,5,2,10,10,6,6,6]
selected_sample['점수'] = score

selected_sample
# Out:
#                                                 tag count  ...  점수
# 141012  {'휴식': 1, '여유': 1, '집': 1, '힐링': 1, '포근한': 1, ...  ...   5
# 62385                        {'휴식': 1, '편안한': 1, '힙한': 1}  ...   5
# 340971             {'편안함': 1, '힐링': 1, '뮤지컬': 1, '휴식': 1}  ...   4
# 155288  {'저녁': 1, '잔잔한': 1, '눈': 1, '분위기': 1, '일상': 3,...  ...  10
# 219799                        {'치유': 1, '휴식': 1, '위로': 1}  ...   3
# 79821                                 {'편안함': 1, '휴식': 1}  ...   3
# 354905  {'따듯한': 1, '휴식': 1, '잔잔한': 1, '퇴근': 1, '사색': 1...  ...  10
# 20689               {'위로': 1, '휴식': 1, '힐링': 1, '편안한': 1}  ...   6
# 120873                       {'휴식': 1, '편안함': 1, '마음': 1}  ...   8
# 344988  {'카페': 1, '잔잔한': 2, '기억': 1, '휴식': 3, '일상': 1,...  ...   7
# 152046                                 {'휴식': 1, '일상': 1}  ...   7
# 152274  {'집': 2, '힐링': 2, '휴식': 2, '몽환적인': 1, '분위기': 1...  ...   3
# 393213                                {'휴식': 1, '편안한': 1}  ...   2
# 70248   {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...  10
# 339380              {'잔잔': 1, '휴식': 1, '낮잠': 1, '편안한': 1}  ...   3
#
# [15 rows x 8 columns]

# %% [markdown]
# ## 노래 추천시 가수 고려

# %%
fav_artist = list(selected_sample[selected_sample['점수']==mx]['아티스트 리스트'])
fav_artist
# Out:
# [['카더가든'], ['커피소년'], ['공부 도우미']]

# %%
hate_artist = list(selected_sample[selected_sample['점수']==mn]['아티스트 리스트'])
hate_artist
# Out:
# [['Jjj']]

# %%
# selected['fav_artist'] = selected['아티스트 리스트'].apply(lambda x: True if x in fav_artist else False)
# fav_artist_song = selected[selected['fav_artist']==True]
# fav_artist_song
song_data['가중치']=0  # 가중치 열 생성
song_data['fav_artist'] = song_data['아티스트 리스트'].apply(lambda x: True if x in fav_artist else False)
fav_artist_index = song_data[song_data['fav_artist']==True].index.values.tolist()

for i in fav_artist_index:
  song_data['가중치'].iloc[i]  = song_data['가중치'].iloc[i] + 0.3


song_data.iloc[fav_artist_index].tail(30)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#                                                 tag count  ... fav_artist
# 343074                {'힐링': 1, '휴식': 1, '밤': 1, '새벽': 1}  ...       True
# 344739                                 {'힐링': 1, '휴식': 1}  ...       True
# 345393  {'휴식': 24, '힐링': 25, '기분전환': 9, '비오는날': 5, '흐린...  ...       True
# 348932  {'기분전환': 7, '잔잔한': 4, '가을': 1, '힐링': 11, '휴식':...  ...       True
# 350153                                 {'봄': 1, '잔잔한': 1}  ...       True
# 350837  {'이별': 29, '헤어짐': 1, '슬픈': 2, '사랑': 10, '슬픔': ...  ...       True
# 351253                {'힐링': 2, '휴식': 2, '밤': 1, '새벽': 1}  ...       True
# 351689                      {'산책': 1, '기분전환': 1, '여행': 1}  ...       True
# 352473  {'위로': 2, '휴식': 4, '잔잔한': 5, '봄': 7, '낮잠': 1, ...  ...       True
# 352989  {'사랑': 15, '봄': 5, '달달': 2, '연애': 4, '설렘': 7, ...  ...       True
# 354133  {'잔잔한': 7, '새벽감성': 3, '새벽': 6, '청춘': 1, '겨울': ...  ...       True
# 354833                                          {'운동': 1}  ...       True
# 354905  {'따듯한': 1, '휴식': 1, '잔잔한': 1, '퇴근': 1, '사색': 1...  ...       True
# 355168  {'까페': 4, '잔잔한': 3, '비오는날': 1, '휴식': 4, '봄': 1...  ...       True
# 355895  {'카페': 1, '잔잔한': 8, '기분전환': 2, '사랑': 3, '가을': ...  ...       True
# 364484  {'스트레스': 1, '휴식': 2, '사랑': 5, '여행': 2, '기분전환':...  ...       True
# 364498  {'힐링': 1, '휴식': 1, '밤': 2, '새벽': 2, '퇴근': 1, '...  ...       True
# 366385   {'겨울': 1, '겨울밤': 1, '새벽': 1, '새벽감성': 1, '저녁': 1}  ...       True
# 367847  {'힐링': 31, '휴식': 28, '추억': 15, '회상': 13, '기분전환...  ...       True
# 374067  {'새해': 1, '여행': 2, '기분전환': 16, '힐링': 31, '휴식':...  ...       True
# 374590  {'위로': 1, '힘내': 1, '응원': 1, '운동': 1, '드라이브': 1...  ...       True
# 375305                      {'산책': 1, '기분전환': 1, '여행': 1}  ...       True
# 376625                {'힐링': 1, '휴식': 1, '밤': 1, '새벽': 1}  ...       True
# 379064  {'출근길': 6, '휴식': 13, '힐링': 15, '여행': 5, '산책': ...  ...       True
# 385495  {'비오는날': 1, '가을': 1, '카페': 1, '휴식': 2, '감성자극':...  ...       True
# 387781  {'겨울': 3, '휴식': 2, '밤': 4, '카페': 2, '잔잔한': 4, ...  ...       True
# 388817  {'가을': 3, '따듯한': 1, '따스한': 1, '주말': 2, '겨울': 2...  ...       True
# 388818                {'힐링': 1, '휴식': 1, '밤': 1, '새벽': 1}  ...       True
# 392483                                          {'가을': 1}  ...       True
# 394761                      {'산책': 1, '기분전환': 1, '여행': 1}  ...       True
#
# [30 rows x 9 columns]

# %%
song_data['hate_artist'] = song_data['아티스트 리스트'].apply(lambda x: True if x in hate_artist else False)
hate_artist_index = song_data[song_data['hate_artist']==True].index.values.tolist()

for i in hate_artist_index:
  song_data['가중치'].iloc[i]  = song_data['가중치'].iloc[i] - 0.2


song_data.iloc[hate_artist_index].tail(30)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#                   tag count        tag max  ... fav_artist hate_artist
# 92262    {'휴식': 1, '힐링': 1}   ['휴식', '힐링']  ...      False        True
# 185162   {'여름': 1, '새해': 1}   ['여름', '새해']  ...      False        True
# 393213  {'휴식': 1, '편안한': 1}  ['휴식', '편안한']  ...      False        True
#
# [3 rows x 10 columns]

# %%
fav_tag = list(selected_sample[selected_sample['점수']==mx]['tag max'])
fav_tag
# Out:
# ["['일상', '달달', '휴식']",
#  "['따듯한', '휴식', '잔잔한', '퇴근', '사색', '집', '위로', '힐링', '부드러운']",
#  "['휴식', '잔잔한', '행복', '집', '힐링', '편안한']"]

# %%
song_data['fav_tag'] = song_data['tag max'].apply(lambda x: True if x in fav_tag else False)
fav_tag_index = song_data[song_data['fav_tag']==True].index.values.tolist()

for i in fav_tag_index:
  song_data['가중치'].iloc[i]  = song_data['가중치'].iloc[i] + 0.3


song_data.iloc[fav_tag_index].tail(30)






# selected['fav_tag'] = selected['max_key'].apply(lambda x: True if x in fav_tag else False)
# fav_tag_song = selected[selected['fav_tag']==True]
# fav_tag_song
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#                                                 tag count  ... fav_tag
# 13698   {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 37438   {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 40096   {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 70248   {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 71577   {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 93298   {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 106067  {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 136426  {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 155288  {'저녁': 1, '잔잔한': 1, '눈': 1, '분위기': 1, '일상': 3,...  ...    True
# 174323  {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 187613  {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 201676  {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 210546  {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 234111  {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 243461  {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 249019  {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 295727  {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 297625  {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 343781  {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...    True
# 354905  {'따듯한': 1, '휴식': 1, '잔잔한': 1, '퇴근': 1, '사색': 1...  ...    True
#
# [20 rows x 11 columns]

# %%
hate_tag = list(selected_sample[selected_sample['점수']==mn]['tag max'])

song_data['hate_tag'] = song_data['tag max'].apply(lambda x: True if x in hate_tag else False)
hate_tag_index = song_data[song_data['hate_tag']==True].index.values.tolist()

for i in hate_tag_index:
  song_data['가중치'].iloc[i]  = song_data['가중치'].iloc[i] - 0.2


song_data.iloc[hate_tag_index].tail(30)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#                                                 tag count  ... hate_tag
# 93941   {'휴식': 3, '밤': 2, '겨울밤': 1, '새벽감성': 2, '새벽': 2...  ...     True
# 100596  {'휴식': 2, '비': 1, '잔잔한': 1, '독서': 1, '힐링': 1, ...  ...     True
# 138093  {'휴식': 2, '드라이브': 1, '기분전환': 1, '분위기': 1, '편안한...  ...     True
# 142859                                {'휴식': 1, '편안한': 1}  ...     True
# 213003                                {'휴식': 1, '편안한': 1}  ...     True
# 216033  {'잔잔': 1, '휴식': 2, '여유': 1, '바다': 1, '편안한': 2,...  ...     True
# 217165  {'드라이브': 1, '휴식': 2, '기분전환': 1, '분위기': 1, '편안한...  ...     True
# 239496  {'힐링': 1, '휴식': 2, '산책': 1, '드라이브': 1, '여행': 1...  ...     True
# 243007                                {'휴식': 1, '편안한': 1}  ...     True
# 270964                                {'휴식': 1, '편안한': 1}  ...     True
# 282701                                {'휴식': 1, '편안한': 1}  ...     True
# 283068  {'드라이브': 1, '휴식': 2, '기분전환': 1, '분위기': 1, '편안한...  ...     True
# 294966  {'잔잔한': 1, '나른한': 1, '카페': 1, '오후': 1, '여행': 1...  ...     True
# 297033  {'집중': 1, '휴식': 2, '책': 1, '여유': 1, '주말': 1, '...  ...     True
# 300215  {'집중': 1, '주말': 1, '나른한': 1, '혼자있을때': 1, '휴식':...  ...     True
# 304437  {'휴식': 2, '주말': 1, '오후': 1, '나른한': 1, '편안한': 2...  ...     True
# 316842  {'휴식': 3, '카페': 1, '여유': 2, '낮잠': 1, '오후': 1, ...  ...     True
# 321110  {'휴식': 3, '카페': 1, '커피': 1, '커피숍': 1, '밤': 2, ...  ...     True
# 324107                                {'휴식': 1, '편안한': 1}  ...     True
# 325331                                {'휴식': 1, '편안한': 1}  ...     True
# 338504                                {'휴식': 1, '편안한': 1}  ...     True
# 341417  {'휴식': 2, '낮잠': 1, '편안한': 2, '밤': 1, '새벽': 1, ...  ...     True
# 342902                                {'휴식': 1, '편안한': 1}  ...     True
# 344988  {'카페': 1, '잔잔한': 2, '기억': 1, '휴식': 3, '일상': 1,...  ...     True
# 353911  {'카페': 1, '오후': 1, '커피': 1, '와인': 1, '집중': 1, ...  ...     True
# 369908                                {'휴식': 1, '편안한': 1}  ...     True
# 383221  {'휴식': 2, '카페': 1, '커피': 1, '커피숍': 1, '낮잠': 1,...  ...     True
# 385811                                {'휴식': 1, '편안한': 1}  ...     True
# 387465                                {'휴식': 1, '편안한': 1}  ...     True
# 393213                                {'휴식': 1, '편안한': 1}  ...     True
#
# [30 rows x 12 columns]

# %%
fav_emotion = list(selected_sample[selected_sample['점수']==mx]['emotion max'])
print(fav_emotion)

hate_emotion = list(selected_sample[selected_sample['점수']==mn]['emotion max'])
print(hate_emotion)
# Out:
# ["['편안한', '행복한', '잔잔한']", "['잔잔한', '편안한']", "['잔잔한', '행복한', '편안한']"]
# ["['잔잔한', '편안한']"]

# %%
song_data['fav_emotion'] = song_data['emotion max'].apply(lambda x: True if x in fav_emotion else False)
fav_emotion_index = song_data[song_data['fav_emotion']==True].index.values.tolist()

for i in fav_emotion_index:
  song_data['가중치'].iloc[i]  = song_data['가중치'].iloc[i] + 0.3


song_data.iloc[fav_emotion_index].tail(30)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#                                                 tag count  ... fav_emotion
# 377165                         {'집': 1, '잔잔': 1, '휴식': 1}  ...        True
# 380390                                {'가을': 1, '편안함': 1}  ...        True
# 380549                                {'휴식': 1, '편안함': 1}  ...        True
# 380644                              {'책읽을때': 1, '편안한': 1}  ...        True
# 382421                                {'잔잔한': 1, '치유': 1}  ...        True
# 382465                        {'명상': 3, '마음': 3, '집중': 1}  ...        True
# 382582                              {'책읽을때': 1, '편안한': 1}  ...        True
# 383221  {'휴식': 2, '카페': 1, '커피': 1, '커피숍': 1, '낮잠': 1,...  ...        True
# 383750  {'휴식': 1, '주말': 1, '봄날': 1, '데이트': 1, '감성적인': ...  ...        True
# 384273                                {'잔잔한': 1, '치유': 1}  ...        True
# 384423   {'카페': 2, '따뜻한': 1, '편안한': 2, '위로': 1, '조용한': 1}  ...        True
# 385195                                {'카페': 1, '편안함': 1}  ...        True
# 385429                              {'감미로운': 1, '편안한': 1}  ...        True
# 385518  {'명상': 3, '마음': 3, '휴식': 1, '겨울': 1, '활기찬': 1,...  ...        True
# 385811                                {'휴식': 1, '편안한': 1}  ...        True
# 385838  {'새벽': 1, '조용한': 1, '편안한': 1, '연말': 1, '노동요': ...  ...        True
# 386910                        {'휴식': 1, '힐링': 1, '마음': 1}  ...        True
# 387465                                {'휴식': 1, '편안한': 1}  ...        True
# 388014                                {'잔잔한': 1, '일상': 1}  ...        True
# 388673                              {'책읽을때': 1, '편안한': 1}  ...        True
# 388677                                {'카페': 1, '편안함': 1}  ...        True
# 390689  {'잔잔한': 1, '치유': 1, '힐링': 1, '몽환적인': 1, '편안한': 1}  ...        True
# 392121                        {'퇴근': 1, '힐링': 1, '휴식': 1}  ...        True
# 392465                       {'휴식': 1, '힐링': 1, '편안한': 1}  ...        True
# 393052                                {'카페': 1, '편안함': 1}  ...        True
# 393213                                {'휴식': 1, '편안한': 1}  ...        True
# 394399  {'달달': 1, '분위기': 2, '일상': 2, '잔잔한': 1, '밤': 1,...  ...        True
# 394414                                {'카페': 1, '편안함': 1}  ...        True
# 395190                         {'햇살': 1, '봄': 1, '카페': 1}  ...        True
# 395357                      {'휴식': 1, '여유': 1, '부드러운': 1}  ...        True
#
# [30 rows x 13 columns]

# %%
song_data['hate_emotion'] = song_data['emotion max'].apply(lambda x: True if x in hate_emotion else False)
hate_emotion_index = song_data[song_data['hate_emotion']==True].index.values.tolist()

for i in hate_emotion_index:
  song_data['가중치'].iloc[i]  = song_data['가중치'].iloc[i] - 0.2


song_data.iloc[hate_emotion_index].tail(30)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#                                                 tag count  ... hate_emotion
# 374954                              {'책읽을때': 1, '편안한': 1}  ...         True
# 375032                                {'카페': 1, '편안함': 1}  ...         True
# 375336   {'겨울': 1, '커피': 1, '마음': 1, '부드러운': 1, '따뜻한': 1}  ...         True
# 375798     {'카페': 1, '집': 1, '커피': 1, '일상': 1, '스트레스': 1}  ...         True
# 375828                                 {'휴식': 1, '일상': 1}  ...         True
# 375867                                {'잔잔한': 1, '치유': 1}  ...         True
# 380390                                {'가을': 1, '편안함': 1}  ...         True
# 380549                                {'휴식': 1, '편안함': 1}  ...         True
# 380644                              {'책읽을때': 1, '편안한': 1}  ...         True
# 382421                                {'잔잔한': 1, '치유': 1}  ...         True
# 382465                        {'명상': 3, '마음': 3, '집중': 1}  ...         True
# 382582                              {'책읽을때': 1, '편안한': 1}  ...         True
# 383221  {'휴식': 2, '카페': 1, '커피': 1, '커피숍': 1, '낮잠': 1,...  ...         True
# 383750  {'휴식': 1, '주말': 1, '봄날': 1, '데이트': 1, '감성적인': ...  ...         True
# 384273                                {'잔잔한': 1, '치유': 1}  ...         True
# 384423   {'카페': 2, '따뜻한': 1, '편안한': 2, '위로': 1, '조용한': 1}  ...         True
# 385195                                {'카페': 1, '편안함': 1}  ...         True
# 385429                              {'감미로운': 1, '편안한': 1}  ...         True
# 385518  {'명상': 3, '마음': 3, '휴식': 1, '겨울': 1, '활기찬': 1,...  ...         True
# 385811                                {'휴식': 1, '편안한': 1}  ...         True
# 385838  {'새벽': 1, '조용한': 1, '편안한': 1, '연말': 1, '노동요': ...  ...         True
# 387465                                {'휴식': 1, '편안한': 1}  ...         True
# 388014                                {'잔잔한': 1, '일상': 1}  ...         True
# 388673                              {'책읽을때': 1, '편안한': 1}  ...         True
# 388677                                {'카페': 1, '편안함': 1}  ...         True
# 390689  {'잔잔한': 1, '치유': 1, '힐링': 1, '몽환적인': 1, '편안한': 1}  ...         True
# 393052                                {'카페': 1, '편안함': 1}  ...         True
# 393213                                {'휴식': 1, '편안한': 1}  ...         True
# 394399  {'달달': 1, '분위기': 2, '일상': 2, '잔잔한': 1, '밤': 1,...  ...         True
# 394414                                {'카페': 1, '편안함': 1}  ...         True
#
# [30 rows x 14 columns]

# %%
song_data[song_data['가중치']>0.3]
# Out:
#                                                 tag count  ... hate_emotion
# 109     {'커피': 6, '기분전환': 4, '댄스': 1, '드라이브': 3, '휴식':...  ...        False
# 774                       {'기분전환': 1, '스트레스': 1, '여름': 1}  ...        False
# 5066    {'비오는날': 2, '힐링': 4, '휴식': 5, '잔잔한': 2, '봄': 2...  ...        False
# 6680                        {'휴식': 1, '힐링': 1, '기분전환': 1}  ...        False
# 9988                         {'비오는날': 1, '밤': 1, '새벽': 1}  ...        False
# ...                                                   ...  ...          ...
# 387781  {'겨울': 3, '휴식': 2, '밤': 4, '카페': 2, '잔잔한': 4, ...  ...        False
# 388817  {'가을': 3, '따듯한': 1, '따스한': 1, '주말': 2, '겨울': 2...  ...        False
# 388818                {'힐링': 1, '휴식': 1, '밤': 1, '새벽': 1}  ...        False
# 392483                                          {'가을': 1}  ...        False
# 394761                      {'산책': 1, '기분전환': 1, '여행': 1}  ...        False
#
# [275 rows x 14 columns]

# %% [markdown]
# ## 사용자가 재추천을 원했다고 가정

# %%
selected = song_data.iloc[res]

wgt_rec = selected.sort_values('가중치',ascending=False).iloc[:5]   #가중치를 고려하여 5개 추천
wgt_rec
# Out:
#                                                 tag count  ... hate_emotion
# 187613  {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...        False
# 155288  {'저녁': 1, '잔잔한': 1, '눈': 1, '분위기': 1, '일상': 3,...  ...        False
# 70248   {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...        False
# 354905  {'따듯한': 1, '휴식': 1, '잔잔한': 1, '퇴근': 1, '사색': 1...  ...         True
# 37438   {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...        False
#
# [5 rows x 14 columns]

# %%
rand_rec  = selected.sample(n=10,random_state=1110)
rand_rec
# Out:
#                                             tag count  ... hate_emotion
# 264387                            {'편안함': 1, '휴식': 1}  ...        False
# 323369       {'휴식': 1, '스트레스': 1, '일상': 1, '기분전환': 1}  ...        False
# 120873                   {'휴식': 1, '편안함': 1, '마음': 1}  ...        False
# 32275          {'휴식': 1, '힐링': 1, '퇴근길': 1, '편안한': 1}  ...        False
# 269794                   {'휴식': 1, '편안함': 1, '마음': 1}  ...        False
# 133828  {'휴식': 1, '밤': 1, '일상': 1, '침대': 1, '편안한': 1}  ...        False
# 26230                             {'휴식': 1, '편안함': 1}  ...         True
# 101043          {'퇴근': 1, '휴식': 1, '저녁': 1, '편안한': 1}  ...        False
# 185541                    {'밤': 1, '휴식': 1, '편안한': 1}  ...        False
# 378256                   {'휴식': 1, '편안함': 1, '마음': 1}  ...        False
#
# [10 rows x 14 columns]

# %%
selected_sample = pd.concat([wgt_rec,rand_rec])
selected_sample['점수']=0
selected_sample
# Out:
#                                                 tag count  ... 점수
# 187613  {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...  0
# 155288  {'저녁': 1, '잔잔한': 1, '눈': 1, '분위기': 1, '일상': 3,...  ...  0
# 70248   {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...  0
# 354905  {'따듯한': 1, '휴식': 1, '잔잔한': 1, '퇴근': 1, '사색': 1...  ...  0
# 37438   {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...  0
# 264387                                {'편안함': 1, '휴식': 1}  ...  0
# 323369           {'휴식': 1, '스트레스': 1, '일상': 1, '기분전환': 1}  ...  0
# 120873                       {'휴식': 1, '편안함': 1, '마음': 1}  ...  0
# 32275              {'휴식': 1, '힐링': 1, '퇴근길': 1, '편안한': 1}  ...  0
# 269794                       {'휴식': 1, '편안함': 1, '마음': 1}  ...  0
# 133828      {'휴식': 1, '밤': 1, '일상': 1, '침대': 1, '편안한': 1}  ...  0
# 26230                                 {'휴식': 1, '편안함': 1}  ...  0
# 101043              {'퇴근': 1, '휴식': 1, '저녁': 1, '편안한': 1}  ...  0
# 185541                        {'밤': 1, '휴식': 1, '편안한': 1}  ...  0
# 378256                       {'휴식': 1, '편안함': 1, '마음': 1}  ...  0
#
# [15 rows x 15 columns]

# %%
name = list(selected_sample['곡 제목'])
score=[]
for i in name:
  s = input(f'\'{i}\' 의 점수를 입력해주세요   ',)
  score.append(int(s))


selected_sample['점수'] = score

selected_sample
# Out:
# 'Brahms : Violin Concerto In D Major Op.77 - II. Adagio (브람스 : 바이올린 협주곡 라장조 작품번호 77 - 2악장)' 의 점수를 입력해주세요   10
# 'Somebody (Feat. Paloalto, Ugly Duck)' 의 점수를 입력해주세요   10
# 'Brahms : Double Concerto For Violin And Cello In A Minor Op.102 - II. Andante (브람스 : 바이올린과 첼로를 위한 2중주 협주곡 가단조 작품번호 102 - 2악장)' 의 점수를 입력해주세요   3
# '서서히' 의 점수를 입력해주세요   10
# 'Brahms : Rhapsody No.1 In B Minor Op.79 (브람스 : 랩소디 1번 나단조 작품번호 79)' 의 점수를 입력해주세요   4
# 'God Has Changed Me' 의 점수를 입력해주세요   5
# 'Rolling Stone' 의 점수를 입력해주세요   2
# 'Bach : Cello Suite No.6 In D Major BWV.1012 - I. Prelude (바흐 : 무반주 첼로 모음곡 6번 라장조 - 1번. 전주곡)' 의 점수를 입력해주세요   6
# 'In An Old Castle' 의 점수를 입력해주세요   2
# 'ミクロワルツ : 1 / Micro Waltz : 1' 의 점수를 입력해주세요   1
# 'Schumann : 5 Stucke Im Volkston Op.102 - II. Langsam (슈만 : 5개의 민요풍의 소품 작품번호 102 - 2번)' 의 점수를 입력해주세요   1
# '꽃길을 걸어가는 그대에게' 의 점수를 입력해주세요   8
# 'Que Reste-T-Il De Nos Amours (우리의 사랑에 무엇이 남았나요)' 의 점수를 입력해주세요   2
# '캐논 변주곡 (영화 `엽기적인 그녀`, `클래식` OST)' 의 점수를 입력해주세요   10
# 'Puccini : Tosca - E Lucean Le Stelle (푸치니 : 토스카 - 별은 빛나건만)' 의 점수를 입력해주세요   8
#                                                 tag count  ...  점수
# 187613  {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...  10
# 155288  {'저녁': 1, '잔잔한': 1, '눈': 1, '분위기': 1, '일상': 3,...  ...  10
# 70248   {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...   3
# 354905  {'따듯한': 1, '휴식': 1, '잔잔한': 1, '퇴근': 1, '사색': 1...  ...  10
# 37438   {'휴식': 1, '잔잔한': 1, '행복': 1, '집': 1, '힐링': 1, ...  ...   4
# 264387                                {'편안함': 1, '휴식': 1}  ...   5
# 323369           {'휴식': 1, '스트레스': 1, '일상': 1, '기분전환': 1}  ...   2
# 120873                       {'휴식': 1, '편안함': 1, '마음': 1}  ...   6
# 32275              {'휴식': 1, '힐링': 1, '퇴근길': 1, '편안한': 1}  ...   2
# 269794                       {'휴식': 1, '편안함': 1, '마음': 1}  ...   1
# 133828      {'휴식': 1, '밤': 1, '일상': 1, '침대': 1, '편안한': 1}  ...   1
# 26230                                 {'휴식': 1, '편안함': 1}  ...   8
# 101043              {'퇴근': 1, '휴식': 1, '저녁': 1, '편안한': 1}  ...   2
# 185541                        {'밤': 1, '휴식': 1, '편안한': 1}  ...  10
# 378256                       {'휴식': 1, '편안함': 1, '마음': 1}  ...   8
#
# [15 rows x 15 columns]

# %%
# 재추천을 원할 시 위에서와 동일하게 높은 점수를 받은 태그, 가수, 감정 가중치 +, 낮은 점수를 받은 태그, 가수, 감정 가중치 -
